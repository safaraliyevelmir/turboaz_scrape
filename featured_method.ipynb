# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("turboaz.csv")

# %%
df
# Out:
#        Unnamed: 0 Şəhər       Marka     Model  Buraxılış ili         Ban növü  \
# 0               0  Bakı  Land Rover  RR Sport           2015  Offroader / SUV
# 1               1  Bakı      Nissan     Tiida           2012          Hetçbek
# 2               2  Bakı    Mercedes  G 63 AMG           2018  Offroader / SUV
# 3               3  Bakı       Isuzu  NPR75L-K           2022       Yük maşını
# 4               4  Bakı        Ford   Transit           2007       Yük maşını
# ...           ...   ...         ...       ...            ...              ...
# 10791       10791  Bakı    Mercedes     E 250           2012            Sedan
# 10792       10792  Bakı         BMW        X5           2016  Offroader / SUV
# 10793       10793  Bakı      Toyota     Prius           2011          Liftbek
# 10794       10794  Bakı        Opel     Astra           2005          Hetçbek
# 10795       10795  Bakı  LADA (VAZ)      2107           2007            Sedan
#
# ...

# %%
type(df['Qəzalı'].loc[0])
# Out:
# float

# %%
df.isnull().sum()/len(df)*100
# Out:
# Unnamed: 0                   0.000000
# Şəhər                        0.000000
# Marka                        0.000000
# Model                        0.000000
# Buraxılış ili                0.000000
# Ban növü                     0.000000
# Rəng                         0.000000
# Mühərrik                     0.000000
# Yürüş                        0.000000
# Sürətlər qutusu              0.000000
# Ötürücü                      0.000000
# Yeni                         0.000000
# Vəziyyəti                    1.926639
# Hansı bazar üçün yığılıb    37.449055
# Yerlərin sayı               33.929233
# Sahiblər                    40.987403
# Qəzalı                      99.805484
# dtype: float64

# %%
df = df.drop('Qəzalı',axis=1)

# %%
imputer = SimpleImputer(strategy="most_frequent")
imputer.fit_transform(df.select_dtypes(exclude="string"))
# Out:
# array([[0, 'Bakı', 'Land Rover', ..., 'Rəsmi diler', '5', '1'],
#        [1, 'Bakı', 'Nissan', ..., 'Yaponiya', '5', '1'],
#        [2, 'Bakı', 'Mercedes', ..., 'Rəsmi diler', '7', '1'],
#        ...,
#        [10793, 'Bakı', 'Toyota', ..., 'Amerika', '5', '1'],
#        [10794, 'Bakı', 'Opel', ..., 'Avropa', '5', '1'],
#        [10795, 'Bakı', 'LADA (VAZ)', ..., 'Rusiya', '5', '1']],
#       dtype=object)

# %%
df['Vəziyyəti']=df['Vəziyyəti'].fillna(df['Vəziyyəti'].mode()[0])

# %%
df
# Out:
#        Unnamed: 0 Şəhər       Marka     Model  Buraxılış ili         Ban növü  \
# 0               0  Bakı  Land Rover  RR Sport           2015  Offroader / SUV
# 1               1  Bakı      Nissan     Tiida           2012          Hetçbek
# 2               2  Bakı    Mercedes  G 63 AMG           2018  Offroader / SUV
# 3               3  Bakı       Isuzu  NPR75L-K           2022       Yük maşını
# 4               4  Bakı        Ford   Transit           2007       Yük maşını
# ...           ...   ...         ...       ...            ...              ...
# 10791       10791  Bakı    Mercedes     E 250           2012            Sedan
# 10792       10792  Bakı         BMW        X5           2016  Offroader / SUV
# 10793       10793  Bakı      Toyota     Prius           2011          Liftbek
# 10794       10794  Bakı        Opel     Astra           2005          Hetçbek
# 10795       10795  Bakı  LADA (VAZ)      2107           2007            Sedan
#
# ...

# %%
df.isnull().sum()/len(df)*100
# Out:
# Unnamed: 0                   0.000000
# Şəhər                        0.000000
# Marka                        0.000000
# Model                        0.000000
# Buraxılış ili                0.000000
# Ban növü                     0.000000
# Rəng                         0.000000
# Mühərrik                     0.000000
# Yürüş                        0.000000
# Sürətlər qutusu              0.000000
# Ötürücü                      0.000000
# Yeni                         0.000000
# Vəziyyəti                    0.000000
# Hansı bazar üçün yığılıb    37.449055
# Yerlərin sayı               33.929233
# Sahiblər                    40.987403
# dtype: float64

# %%
df["Hansı bazar üçün yığılıb"]=df["Hansı bazar üçün yığılıb"].fillna(df["Hansı bazar üçün yığılıb"].mode()[0])

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# Şəhər                          0
# Marka                          0
# Model                          0
# Buraxılış ili                  0
# Ban növü                       0
# Rəng                           0
# Mühərrik                       0
# Yürüş                          0
# Sürətlər qutusu                0
# Ötürücü                        0
# Yeni                           0
# Vəziyyəti                      0
# Hansı bazar üçün yığılıb       0
# Yerlərin sayı               3663
# Sahiblər                    4425
# dtype: int64

# %%
df["Yerlərin sayı"].unique()
# Out:
# array([nan, '5', '7', '4', '6', '3', '2', '1', '8+'], dtype=object)

# %%
df["Yerlərin sayı"]=pd.to_numeric(df["Yerlərin sayı"],errors="coerce")

# %%
mean = int(df['Yerlərin sayı'].mean())
mean
# Out:
# 5

# %%
df['Yerlərin sayı'].fillna(mean, inplace=True)

# %%
df["Sahiblər"].unique()
# Out:
# array([nan, '1', '2', '0', '3', '4 və daha çox'], dtype=object)

# %%
df["Sahiblər"] =pd.to_numeric(df["Sahiblər"],errors="coerce")

# %%
median = df["Sahiblər"].median()

# %%
df['Sahiblər'].fillna(median, inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Şəhər                       0
# Marka                       0
# Model                       0
# Buraxılış ili               0
# Ban növü                    0
# Rəng                        0
# Mühərrik                    0
# Yürüş                       0
# Sürətlər qutusu             0
# Ötürücü                     0
# Yeni                        0
# Vəziyyəti                   0
# Hansı bazar üçün yığılıb    0
# Yerlərin sayı               0
# Sahiblər                    0
# dtype: int64

# %%
df2 = df["Mühərrik"].str.split("/",expand=True)

# %%
df = pd.concat([df,df2],axis=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [106], line 1
# ----> 1 df=df.drop("Mühərrik",axis=1)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py?line=324'>325</a> if len(args) > num_allow_args:
#     <a href='file:///~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py?line=325'>326</a>     warnings.warn(
#     <a href='file:///~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py?line=326'>327</a>         msg.format(arguments=_format_argument_list(allow_args)),
#     <a href='file:///~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py?line=327'>328</a>         FutureWarning,
# ...

# %%
# Out:
#        Unnamed: 0 Şəhər       Marka     Model  Buraxılış ili         Ban növü  \
# 0               0  Bakı  Land Rover  RR Sport           2015  Offroader / SUV
# 1               1  Bakı      Nissan     Tiida           2012          Hetçbek
# 2               2  Bakı    Mercedes  G 63 AMG           2018  Offroader / SUV
# 3               3  Bakı       Isuzu  NPR75L-K           2022       Yük maşını
# 4               4  Bakı        Ford   Transit           2007       Yük maşını
# ...           ...   ...         ...       ...            ...              ...
# 10791       10791  Bakı    Mercedes     E 250           2012            Sedan
# 10792       10792  Bakı         BMW        X5           2016  Offroader / SUV
# 10793       10793  Bakı      Toyota     Prius           2011          Liftbek
# 10794       10794  Bakı        Opel     Astra           2005          Hetçbek
# 10795       10795  Bakı  LADA (VAZ)      2107           2007            Sedan
#
# ...
